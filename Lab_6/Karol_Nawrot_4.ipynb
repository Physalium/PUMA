# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_swiss_roll
X, color = make_swiss_roll(1000, noise=0.2)
X
# Out:
# array([[  7.56629912,  19.43611908,  -8.7525292 ],
#        [ -0.63169269,   8.27460582, -10.94511709],
#        [  0.81949647,  11.79696638, -10.98343746],
#        ...,
#        [ -9.29263584,   9.72028447,   0.04036776],
#        [ -6.44321641,  19.26759378,   5.85274263],
#        [  6.02610943,  10.54718226,  -1.55615209]])

# %%
fig = plt.figure(figsize=plt.figaspect(0.5))

pca = PCA(n_components=2)
X_PCA = pca.fit_transform(X)


ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax1.scatter3D(X[:, 0], X[:, 1], X[:, 2], c=color)
ax1.set_title("3D chart before PCA")

ax2 = fig.add_subplot(1, 2, 2)
ax2.scatter(X_PCA[:, 0], X_PCA[:, 1], c=color)
ax2.set_title("2D chart after PCA")
plt.show()
